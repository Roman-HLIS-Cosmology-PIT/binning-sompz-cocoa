# %%
import numpy as np

data =  [np.float64(-0.025), np.float64(0.275), np.float64(0.575), np.float64(0.925), np.float64(1.225), np.float64(1.525), np.float64(1.825), np.float64(2.125), np.float64(2.475), np.float64(2.775), np.float64(3.075)]

for value in data:
    print(f"  - {value}")
# Out:
#   - -0.025
#   - 0.275
#   - 0.575
#   - 0.925
#   - 1.225
#   - 1.525
#   - 1.825
#   - 2.125
#   - 2.475
#   - 2.775
#   - 3.075
